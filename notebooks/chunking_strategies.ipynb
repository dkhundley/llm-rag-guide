# %%
# Importing the necessary Python libraries
import os
import yaml
import pandas as pd
from langchain.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# %%
# Loading the API keys
with open('../keys/api_keys.yaml') as f:
    api_keys = yaml.safe_load(f)

# %%
chat_model = ChatOpenAI(api_key = api_keys['PERPLEXITY_API_KEY'],
                        base_url = 'https://api.perplexity.ai',
                        model = 'llama-3-70b-instruct')

chat_model = ChatOpenAI(api_key = api_keys['OPENAI_API_KEY'],
                        model = 'gpt-4o')

# %%
chat_model.invoke('What is the capital of Illinois?')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in __getattr__(self, item)
#     717                     try:
# --> 718                         return pydantic_extra[item]
#     719                     except KeyError as exc:
#
# KeyError: '__pydantic_serializer__'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-70808d19a81c> in <module>
# ----> 1 chat_model.invoke('What is the capital of Illinois?')
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     272         return cast(
#     273             ChatGeneration,
# --> 274             self.generate_prompt(
#     275                 [self._convert_input(input)],
#     276                 stop=stop,
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     712     ) -> LLMResult:
#     713         prompt_messages = [p.to_messages() for p in prompts]
# --> 714         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     715
#     716     async def agenerate_prompt(
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     569                 if run_managers:
#     570                     run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 571                 raise e
#     572         flattened_outputs = [
#     573             LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     559             try:
#     560                 results.append(
# --> 561                     self._generate_with_cache(
#     562                         m,
#     563                         stop=stop,
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     791         else:
#     792             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 793                 result = self._generate(
#     794                     messages, stop=stop, run_manager=run_manager, **kwargs
#     795                 )
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#     590             response = self.client.create(**payload)
#     591             generation_info = None
# --> 592         return self._create_chat_result(response, generation_info)
#     593
#     594     def _get_request_payload(
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_openai/chat_models/base.py in _create_chat_result(self, response, generation_info)
#     615         generations = []
#     616         if not isinstance(response, dict):
# --> 617             response = response.model_dump()
#     618
#     619         # Sometimes the AI Model calling will get error, we should raise it.
#
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in model_dump(self, mode, include, exclude, by_alias, exclude_unset, exclude_defaults, exclude_none, round_trip, warnings)
#     299             A dictionary representation of the model.
#     300         """
# --> 301         return self.__pydantic_serializer__.to_python(
#     302             self,
#     303             mode=mode,
#
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in __getattr__(self, item)
#     718                         return pydantic_extra[item]
#     719                     except KeyError as exc:
# --> 720                         raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}') from exc
#     721                 else:
#     722                     if hasattr(self.__class__, item):
#
# AttributeError: 'ChatCompletion' object has no attribute '__pydantic_serializer__'

# %%
# Creating the ground truth simulation prompt template
GT_SIMULATION_PROMPT = '''You are an expert evaluator for question-answering systems. Your task is to provide the ideal ground truth answer based on the given question and context. Please follow these guidelines:

1. Question: {question}

2. Context: {context}

3. Instructions:
   - Carefully analyze the question and the provided context.
   - Formulate a comprehensive and accurate answer based solely on the information given in the context.
   - Ensure your answer directly addresses the question.
   - Include all relevant information from the context, but do not add any external knowledge.
   - If the context doesn't contain enough information to fully answer the question, state this clearly and provide the best possible partial answer.
   - Use a formal, objective tone.

Remember, your goal is to provide the ideal answer that should be used as the benchmark for evaluating the AI's performance.'''

# %%
# Creating the prompt engineering emplate to generate the simulated ground truth
gt_generation_prompt = ChatPromptTemplate.from_messages(messages = [
    HumanMessagePromptTemplate.from_template(template = GT_SIMULATION_PROMPT)
])

# Instantiating the Llama 3 model via Perplexity
llama_model = ChatOpenAI(api_key = api_keys['PERPLEXITY_API_KEY'],
                         base_url = 'https://api.perplexity.ai',
                         model = 'llama-3-70b-instruct')

# Creating the inference chain to generate the simulated ground truth
gt_generation_chain = gt_generation_prompt | chat_model

# %%
gt_text = gt_generation_chain.invoke(
    {
        'question': 'What is your favorite coffee?',
        'context': 'I like Starbucks cold brew coffe.'
    }
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in __getattr__(self, item)
#     717                     try:
# --> 718                         return pydantic_extra[item]
#     719                     except KeyError as exc:
#
# KeyError: '__pydantic_serializer__'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6d652b3883c0> in <module>
# ----> 1 gt_text = gt_generation_chain.invoke(
#       2     {
#       3         'question': 'What is your favorite coffee?',
#       4         'context': 'I like Starbucks cold brew coffe.'
#       5     }
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    2873                     input = step.invoke(input, config, **kwargs)
#    2874                 else:
# -> 2875                     input = step.invoke(input, config)
#    2876         # finish the root run
#    2877         except BaseException as e:
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     272         return cast(
#     273             ChatGeneration,
# --> 274             self.generate_prompt(
#     275                 [self._convert_input(input)],
#     276                 stop=stop,
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     712     ) -> LLMResult:
#     713         prompt_messages = [p.to_messages() for p in prompts]
# --> 714         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     715
#     716     async def agenerate_prompt(
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     569                 if run_managers:
#     570                     run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 571                 raise e
#     572         flattened_outputs = [
#     573             LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     559             try:
#     560                 results.append(
# --> 561                     self._generate_with_cache(
#     562                         m,
#     563                         stop=stop,
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     791         else:
#     792             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 793                 result = self._generate(
#     794                     messages, stop=stop, run_manager=run_manager, **kwargs
#     795                 )
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#     590             response = self.client.create(**payload)
#     591             generation_info = None
# --> 592         return self._create_chat_result(response, generation_info)
#     593
#     594     def _get_request_payload(
#
# /var/mobile/Containers/Data/Application/C3395A24-F0CE-4177-9CA3-40BC6BD71074/Documents/site-packages/langchain_openai/chat_models/base.py in _create_chat_result(self, response, generation_info)
#     615         generations = []
#     616         if not isinstance(response, dict):
# --> 617             response = response.model_dump()
#     618
#     619         # Sometimes the AI Model calling will get error, we should raise it.
#
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in model_dump(self, mode, include, exclude, by_alias, exclude_unset, exclude_defaults, exclude_none, round_trip, warnings)
#     299             A dictionary representation of the model.
#     300         """
# --> 301         return self.__pydantic_serializer__.to_python(
#     302             self,
#     303             mode=mode,
#
# /private/var/containers/Bundle/Application/B5718204-B5FE-4685-B2EA-D3EF98873014/Juno.app/pinned-packages/pydantic/main.py in __getattr__(self, item)
#     718                         return pydantic_extra[item]
#     719                     except KeyError as exc:
# --> 720                         raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}') from exc
#     721                 else:
#     722                     if hasattr(self.__class__, item):
#
# AttributeError: 'ChatCompletion' object has no attribute '__pydantic_serializer__'
